# %% [markdown]
# <a href="https://colab.research.google.com/github/anchalvishawakarma/Projects/blob/main/Concrete_Strength_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import data Manipulation Libraries
import pandas as pd
import numpy as np
# Import Data Visualization Library
import matplotlib.pyplot as plt
import seaborn as sns
# Import Filter Warning Library
import warnings
warnings.filterwarnings('ignore')
# import Scikit Learn Library
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostClassifier
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# Customise Descriptive Stats
from collections import OrderedDict

# %%
# Import Dataset using padas function
df=pd.read_csv('/content/Concrete Compressive Strength.csv')
df.sample(5)     #Rdom
# Out:
#      Cement  Blast_Furnace_Slag  Fly Ash   Water  Superplasticizer  \
# 81   318.80               212.5     0.00  155.70             14.30
# 649  166.80               250.2     0.00  203.50              0.00
# 208  212.07                 0.0   121.62  180.31              5.69
# 497  355.00                19.0    97.00  145.00             13.13
# 629  225.00                 0.0     0.00  181.00              0.00
#
#      Coarse_Aggregate  Fine_Aggregate  Age_(day)  \
# 81              852.1          880.40          3
# 649             975.6          692.60          3
# 208            1057.6          779.32        100
# 497             967.0          871.00         28
# 629            1113.0          833.00          7
#
#      Concrete_compressive_strength
# 81                       25.200348
# 649                       6.902344
# 208                      39.610396
# 497                      44.029937
# 629                      11.169511

# %% [markdown]
# Rows  = 1030 <br>
# Columns  = 9 <br>
# Categorical = 0 <br>
# Numericals = 9 <br>
# Objective = Predict Compresive Strength of Cement Composit Mixture. <br>
#
# ![image.png](data:image/png;base64,...)

# %%
# Understand the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast_Furnace_Slag             1030 non-null   float64
#  2   Fly Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse_Aggregate               1030 non-null   float64
#  6   Fine_Aggregate                 1030 non-null   float64
#  7   Age_(day)                      1030 non-null   int64
#  8   Concrete_compressive_strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.6 KB

# %%
# Descriptive Statistics
df.describe()
# Out:
#             Cement  Blast_Furnace_Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.165631           73.895485    54.187136   181.566359
# std     104.507142           86.279104    63.996469    21.355567
# min     102.000000            0.000000     0.000000   121.750000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.270000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse_Aggregate  Fine_Aggregate    Age_(day)  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.203112        972.918592      773.578883    45.662136
# std            5.973492         77.753818       80.175427    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.350000        968.000000      779.510000    28.000000
# 75%           10.160000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#        Concrete_compressive_strength
# count                    1030.000000
# mean                       35.817836
# std                        16.705679
# min                         2.331808
# 25%                        23.707115
# 50%                        34.442774
# 75%                        46.136287
# max                        82.599225

# %%
stats =[]
for i in df.columns:
  numerical_stats = OrderedDict({
      'Feature':i,
      'Max':df[i].max(),
      'Min':df[i].min(),
      'Mean':df[i].mean(),
      'Median':df[i].median(),
      'Std':df[i].std(),
      'Variance':df[i].var(),
      'Skewness':df[i].skew(),
      'Kurtosis':df[i].kurt(),
      '25%':df[i].quantile(0.25),
      '75%':df[i].quantile(0.75),
      'IRO':df[i].quantile(0.75)-df[i].quantile(0.25)
})
  stats.append(numerical_stats)
report=pd.DataFrame(stats)
report.T
# Out:
#                      0                   1            2           3  \
# Feature         Cement  Blast_Furnace_Slag      Fly Ash       Water
# Max              540.0               359.4        200.1       247.0
# Min              102.0                 0.0          0.0      121.75
# Mean        281.165631           73.895485    54.187136  181.566359
# Median           272.9                22.0          0.0       185.0
# Std         104.507142           86.279104    63.996469   21.355567
# Variance  10921.742654         7444.083725  4095.548093  456.060245
# Skewness      0.509517            0.800737     0.537445    0.074324
# Kurtosis     -0.520663           -0.508139    -1.328505    0.122676
# 25%            192.375                 0.0          0.0       164.9
# 75%              350.0              142.95       118.27       192.0
# IRO            157.625              142.95       118.27        27.1
#
#                          4                 5               6            7  \
# Feature   Superplasticizer  Coarse_Aggregate  Fine_Aggregate    Age_(day)
# Max                   32.2            1145.0           992.6        365.0
# Min                    0.0             801.0           594.0          1.0
# Mean              6.203112        972.918592      773.578883    45.662136
# Median                6.35             968.0          779.51         28.0
# Std               5.973492         77.753818       80.175427    63.169912
# Variance         35.682602       6045.656228     6428.099159  3990.437729
# Skewness          0.908113         -0.040206       -0.252979     3.269177
# Kurtosis          1.413186         -0.599001       -0.102165    12.168989
# 25%                    0.0             932.0          730.95          7.0
# 75%                  10.16            1029.4           824.0         56.0
# IRO                  10.16              97.4           93.05         49.0
#
#                                       8
# Feature   Concrete_compressive_strength
# Max                           82.599225
# Min                            2.331808
# Mean                          35.817836
# Median                        34.442774
# Std                           16.705679
# Variance                     279.079717
# Skewness                       0.416922
# Kurtosis                      -0.313844
# 25%                           23.707115
# 75%                           46.136287
# IRO                           22.429171

# %%
plt.figure(figsize=(18,15))
plot=0
for i in df.columns:
  plot+=1
  plt.subplot(3,3,plot)
  sns.distplot(df[i])
  plt.title(i)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.figure(figsize=(18,15))
plot=0
for i in df.columns:
  plot+=1
  plt.subplot(3,3,plot)
  sns.boxenplot(df[i])
  plt.title(i)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Checkinf Colimns Names
df.columns
# Out:
# Index(['Cement', 'Blast_Furnace_Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse_Aggregate', 'Fine_Aggregate', 'Age_(day)',
#        'Concrete_compressive_strength'],
#       dtype='object')

# %%
# split th Data into Train and Test
X= df.drop('Concrete_compressive_strength',axis=1)
X.head()
# Out:
#    Cement  Blast_Furnace_Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse_Aggregate  Fine_Aggregate  Age_(day)
# 0            1040.0           676.0         28
# 1            1055.0           676.0         28
# 2             932.0           594.0        270
# 3             932.0           594.0        365
# 4             978.4           825.5        360

# %%
Y=df['Concrete_compressive_strength']
Y.head()
# Out:
# 0    79.986111
# 1    61.887366
# 2    40.269535
# 3    41.052780
# 4    44.296075
# Name: Concrete_compressive_strength, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3,random_state=21)

# %%
# Scalling Technique
sc = MinMaxScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train.min()
# Out:
# 0.0

# %%
X_train.max()
# Out:
# 1.0000000000000002

# %%
# Model Prepration
model=RandomForestRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.score(X_train,y_train)   # Train dataset - 0.98
model.score(X_test,y_test)    # Test dataset  - 0.90

# Training sccuracy = Test accuracy
# Out:
# 0.9023216707961677

# %%
sns.distplot(y_test-y_pred)
plt.axvline(0,color='red')
plt.show()

# %%
# LinearRegression
# Not Normaly Distributed so dont use Liner Reggresion

model=LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.score(X_train,y_train)   # Train dataset - 0.98
model.score(X_test,y_test)    # Test dataset  - 0.90

# Training sccuracy = Test accuracy
# Out:
# 0.6610280560042987

# %%
# RandomForestRegressor
model=RandomForestRegressor()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.score(X_train,y_train)   # Train dataset - 0.98
model.score(X_test,y_test)    # Test dataset  - 0.90

# Training sccuracy = Test accuracy
# Out:
# 0.9023519571380995

# %%
# Apply Boosting Algorithm
# adaboost and agboost

# %%
model=AdaBoostClassifier(n_estimators=50,learning_rate=1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.score(X_train,y_train)   # Train dataset - 0.98
model.score(X_test,y_test)    # Test dataset  - 0.90

# Training sccuracy = Test accuracy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-79d3b1bd28a4> in <cell line: 0>()
#       1 model=AdaBoostClassifier(n_estimators=50,learning_rate=1)
# ----> 2 model.fit(X_train,y_train)
#       3 y_pred=model.predict(X_test)
#       4 model.score(X_train,y_train)   # Train dataset - 0.98
#       5 model.score(X_test,y_test)    # Test dataset  - 0.90
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py in fit(self, X, y, sample_weight)
#     165
#     166             # Boosting step
# --> 167             sample_weight, estimator_weight, estimator_error = self._boost(
#     168                 iboost, X, y, sample_weight, random_state
#     169             )
#
# /usr/local/lib/python3.11/dist-packages/sklearn/ensemble/_weight_boosting.py in _boost(self, iboost, X, y, sample_weight, random_state)
#     563         estimator = self._make_estimator(random_state=random_state)
#     564
# --> 565         estimator.fit(X, y, sample_weight=sample_weight)
#     566
#     567         y_predict = estimator.predict(X)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input)
#    1017         """
#    1018
# -> 1019         super()._fit(
#    1020             X,
#    1021             y,
#
# /usr/local/lib/python3.11/dist-packages/sklearn/tree/_classes.py in _fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     292
#     293         if is_classification:
# --> 294             check_classification_targets(y)
#     295             y = np.copy(y)
#     296
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     220         "multilabel-sequences",
#     221     ]:
# --> 222         raise ValueError(
#     223             f"Unknown label type: {y_type}. Maybe you are trying to fit a "
#     224             "classifier, which expects discrete classes on a "
#
# ValueError: Unknown label type: continuous. Maybe you are trying to fit a classifier, which expects discrete classes on a regression target with continuous values.

# %%
model=GradientBoostingRegressor(n_estimators=50,learning_rate=1)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.score(X_train,y_train)   # Train dataset - 0.9762799828515198
model.score(X_test,y_test)    # Test dataset  - 0.8702713118501723
# Out:
# 0.9762799828515198
